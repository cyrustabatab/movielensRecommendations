# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn
import wordcloud

# %% [markdown]
# ### The following cell will read the data from the csv files into pandas dataframes

# %%
ratings = pd.read_csv("ratings.csv",encoding='latin-1',sep='\t',usecols=['user_id', 'movie_id','user_embedded_id', 'movie_embedded_id','rating'])

max_userid = ratings['user_id'].drop_duplicates().max()
max_movieid = ratings['movie_id'].drop_duplicates().max()

users = pd.read_csv('users.csv',encoding='latin-1',sep='\t',usecols=['user_id', 'gender','zipcode','age_description','occupation_description'])

movies = pd.read_csv("movies.csv",encoding='latin-1',sep='\t',usecols=['movie_id','title','genres'])

# %%
print(ratings.head())
print(ratings.info())
# Out:
#    user_id  movie_id  rating  user_embedded_id  movie_embedded_id
# 0        1      1193       5                 0               1192
# 1        1       661       3                 0                660
# 2        1       914       3                 0                913
# 3        1      3408       4                 0               3407
# 4        1      2355       5                 0               2354
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000209 entries, 0 to 1000208
# Data columns (total 5 columns):
# user_id              1000209 non-null int64
# movie_id             1000209 non-null int64
# rating               1000209 non-null int64
# user_embedded_id     1000209 non-null int64
# movie_embedded_id    1000209 non-null int64
# dtypes: int64(5)
# memory usage: 38.2 MB
# None

# %%
print(users.head())
print(users.info())
# Out:
#    user_id gender zipcode age_description occupation_description
# 0        1      F   48067             <18           K-12 student
# 1        2      M   70072             56+          self-employed
# 2        3      M   55117           25-34              scientist
# 3        4      M   02460           45-49   executive/managerial
# 4        5      M   55455           25-34                 writer
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6040 entries, 0 to 6039
# Data columns (total 5 columns):
# user_id                   6040 non-null int64
# gender                    6040 non-null object
# zipcode                   6040 non-null object
# age_description           6040 non-null object
# occupation_description    6040 non-null object
# dtypes: int64(1), object(4)
# memory usage: 236.0+ KB
# None

# %%
print(movies.head())
print(movies.info())
# Out:
#    movie_id                               title                        genres
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3883 entries, 0 to 3882
# Data columns (total 3 columns):
# movie_id    3883 non-null int64
# title       3883 non-null object
# genres      3883 non-null object
# dtypes: int64(1), object(2)
# memory usage: 91.1+ KB
# None

# %% [markdown]
# #### Next we will explore the data a bit through summary statistics

# %%
ratings['rating'].fillna(ratings['rating'].median)

print(ratings['rating'].mean())
ratings['rating'].value_counts().plot(kind='bar')

plt.show()

ratings['rating'].value_counts().sort_index(ascending=True).plot(kind='bar')
plt.show()
# Out:
# 3.581564453029317

# %%
ratings['rating'].value_counts()
# Out:
# 4    348971
# 3    261197
# 5    226310
# 2    107557
# 1     56174
# Name: rating, dtype: int64

# %%
combined_dataset = pd.merge(pd.merge(movies,ratings),users)

combined_dataset.sort_values('rating',ascending=False).head(50)
# Out:
#         movie_id                                              title  \
# 0              1                                   Toy Story (1995)
# 489283      2858                             American Beauty (1999)
# 489259      2599                                    Election (1999)
# 489257      2571                                 Matrix, The (1999)
# 489256      2551                                Dead Ringers (1988)
# 489237      2395                                    Rushmore (1998)
# 489236      2391                              Simple Plan, A (1998)
# 489226      2330                        Hands on a Hard Body (1996)
# 489224      2321                               Pleasantville (1998)
# 489212      2248                             Say Anything... (1989)
# 489207      2174                                 Beetlejuice (1988)
# 489190      2064                                  Roger & Me (1989)
# 489172      1916                                  Buffalo 66 (1998)
# 489171      1912                                Out of Sight (1998)
# 489354                  Animation|Comedy     5070       5      M   55344
# 489353                             Drama     5070       5      M   55344
# 489352                      Comedy|Drama     5070       5      M   55344
# 489350                    Comedy|Romance     5070       5      M   55344
# 489347                 Children's|Comedy     5070       5      M   55344
# 489345                            Comedy     5070       5      M   55344
# 489338                   Action|Thriller     5070       5      M   55344
# 489337                      Action|Crime     5070       5      M   55344
# 489325           Adventure|Comedy|Sci-Fi     5070       5      M   55344
# 489322                             Drama     5070       5      M   55344
# 489319              Comedy|Drama|Romance     5070       5      M   55344
# 489314                            Comedy     5070       5      M   55344
# 489302                       Documentary     5070       5      M   55344
# 489300                            Comedy     5070       5      M   55344
# 489296          Adventure|Fantasy|Sci-Fi     5070       5      M   55344
# 489295                             Drama     5070       5      M   55344
# 489294                             Drama     5070       5      M   55344
# 489290                            Comedy     5070       5      M   55344
# 489133                            Comedy     5070       5      M   55344
# 489119                             Drama     5070       5      M   55344
# 489374                            Comedy     5070       5      M   55344
# 489011                     Drama|Mystery     5070       5      M   55344
# 489006                        Sci-Fi|War     5070       5      M   55344
# 489003                         Animation     5070       5      M   55344
#
#        age_description occupation_description
# 0                  <18           K-12 student
# 489283           25-34                 artist
# 489259           25-34                 artist
# 489257           25-34                 artist
# 489256           25-34                 artist
# 489237           25-34                 artist
# 489236           25-34                 artist
# 489226           25-34                 artist
# 489224           25-34                 artist
# 489212           25-34                 artist
# 489207           25-34                 artist
# 489190           25-34                 artist
# 489172           25-34                 artist
# 489171           25-34                 artist
# 489170           25-34                 artist
# 489168           25-34                 artist
# 489157           25-34                 artist
# 489152           25-34                 artist
# 489149           25-34                 artist
# 489145           25-34                 artist
# 489136           25-34                 artist
# 489264           25-34                 artist
# 489286           25-34                 artist
# 489129           25-34                 artist
# 489288           25-34                 artist
# 489358           25-34                 artist
# 489354           25-34                 artist
# 489353           25-34                 artist
# 489352           25-34                 artist
# 489350           25-34                 artist
# 489347           25-34                 artist
# 489345           25-34                 artist
# 489338           25-34                 artist
# 489337           25-34                 artist
# 489325           25-34                 artist
# 489322           25-34                 artist
# 489319           25-34                 artist
# 489314           25-34                 artist
# 489302           25-34                 artist
# 489300           25-34                 artist
# 489296           25-34                 artist
# 489295           25-34                 artist
# 489294           25-34                 artist
# 489290           25-34                 artist
# 489133           25-34                 artist
# 489119           25-34                 artist
# 489374           25-34                 artist
# 489011           25-34                 artist
# 489006           25-34                 artist
# 489003           25-34                 artist

# %%
#count the amount of times each genre occurs

genre_counts = {}

for g in movies['genres']:
    words = g.split('|')
    for word in words:
        if word not in genre_counts:
            genre_counts[word] = 1
        else:
            genre_counts[word] += 1

# %%
genre_counts
# Out:
# {'Action': 503,
#  'Adventure': 283,
#  'Animation': 105,
#  "Children's": 251,
#  'Comedy': 1200,
#  'Crime': 211,
#  'Documentary': 127,
#  'Drama': 1603,
#  'Fantasy': 68,
#  'Film-Noir': 44,
#  'Horror': 343,
#  'Musical': 114,
#  'Mystery': 106,
#  'Romance': 471,
#  'Sci-Fi': 276,
#  'Thriller': 492,
#  'War': 143,
#  'Western': 68}

# %%
plt.figure(figsize=(20,3))
plt.bar(range(len(genre_counts)),list(genre_counts.values()),tick_label=list(genre_counts.keys()))
plt.show()

# %%
age_ranges_count = {}

for a in users['age_description']:
    if a not in age_ranges_count:
        age_ranges_count[a] = 1
    else:
        age_ranges_count[a] += 1

# %%
age_ranges_count
# Out:
# {'18-24': 1103,
#  '25-34': 2096,
#  '35-44': 1193,
#  '45-49': 550,
#  '50-55': 496,
#  '56+': 380,
#  '<18': 222}

# %%
plt.bar(range(len(age_ranges_count)),[222,1103,2096,1193,550,496,380],tick_label=['<18','18-24','25-34','35-44','45-49','50-55','56+'])
plt.show()

# %%
ac_genres = wordcloud.WordCloud(background_color='black').generate_from_frequencies(age_ranges_count)
plt.imshow(wc_genres)
plt.axis('off')
plt.show()

# %%
occupation_counts = {}


for o in users['occupation_description']:
    if o not in occupation_counts:
        occupation_counts[o] = 1
    else:
        occupation_counts[o] += 1

# %%
occupation_counts
# Out:
# {'K-12 student': 195,
#  'academic/educator': 528,
#  'artist': 267,
#  'clerical/admin': 173,
#  'college/grad student': 759,
#  'customer service': 112,
#  'doctor/health care': 236,
#  'executive/managerial': 679,
#  'farmer': 17,
#  'homemaker': 92,
#  'lawyer': 129,
#  'other/not specified': 711,
#  'programmer': 388,
#  'retired': 142,
#  'sales/marketing': 302,
#  'scientist': 144,
#  'self-employed': 241,
#  'technician/engineer': 502,
#  'tradesman/craftsman': 70,
#  'unemployed': 72,
#  'writer': 281}

# %%
plt.figure(figsize=(50,3))
plt.bar(range(len(occupation_counts)),list(occupation_counts.values()),tick_label=list(occupation_counts.keys()))
plt.show()

# %%
oc_genres = wordcloud.WordCloud(background_color='black').generate_from_frequencies(occupation_counts)
plt.imshow(oc_genres)
plt.axis('off')
plt.show()

# %%
wc_genres = wordcloud.WordCloud(background_color='black').generate_from_frequencies(genre_counts)
plt.imshow(wc_genres)
plt.axis('off')
plt.show()

# %% [markdown]
# #### Content Based Filtering and Collaborative Filtering

# %%
movies['genres'].str.split('|')
# Out:
# 0          [Animation, Children's, Comedy]
# 1         [Adventure, Children's, Fantasy]
# 2                        [Comedy, Romance]
# 3                          [Comedy, Drama]
# 4                                 [Comedy]
# 5                [Action, Crime, Thriller]
# 6                        [Comedy, Romance]
# 7                  [Adventure, Children's]
# 8                                 [Action]
# 9            [Action, Adventure, Thriller]
# 10                [Comedy, Drama, Romance]
# 11                        [Comedy, Horror]
# 12                 [Animation, Children's]
# 13                                 [Drama]
# 14            [Action, Adventure, Romance]
# 15                       [Drama, Thriller]
# 16                        [Drama, Romance]
# 17                              [Thriller]
# 18                                [Comedy]
# 19                                [Action]
# 20                 [Action, Comedy, Drama]
# 21                [Crime, Drama, Thriller]
# 22                              [Thriller]
# 23                         [Drama, Sci-Fi]
# 24                        [Drama, Romance]
# 25                                 [Drama]
# 26                                 [Drama]
# 27                               [Romance]
# 28                     [Adventure, Sci-Fi]
# 29                                 [Drama]
#                        ...
# 3853                      [Horror, Sci-Fi]
# 3854                              [Comedy]
# 3855                              [Comedy]
# 3856                   [Adventure, Sci-Fi]
# 3857                   [Adventure, Sci-Fi]
# 3858                      [Comedy, Horror]
# 3859                              [Comedy]
# 3860                              [Horror]
# 3861                      [Horror, Sci-Fi]
# 3862                      [Horror, Sci-Fi]
# 3863                      [Horror, Sci-Fi]
# 3864                              [Sci-Fi]
# 3865                              [Horror]
# 3866                     [Drama, Thriller]
# 3867                    [Sci-Fi, Thriller]
# 3868                              [Horror]
# 3869                              [Horror]
# 3870                              [Horror]
# 3871                              [Horror]
# 3872                              [Horror]
# 3873                              [Comedy]
# 3874                       [Comedy, Drama]
# 3875    [Adventure, Animation, Children's]
# 3876             [Action, Drama, Thriller]
# 3877                            [Thriller]
# 3878                              [Comedy]
# 3879                               [Drama]
# 3880                               [Drama]
# 3881                               [Drama]
# 3882                     [Drama, Thriller]
# Name: genres, Length: 3883, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tf = TfidfVectorizer(analyzer='word',ngram_range=(1,2),min_df=0,stop_words='english')
tfidf_matrix = tf.fit_transform(movies['genres'].str.split('|').fillna("").astype('str'))

# %%
tfidf_matrix.shape
# Out:
# (3883, 127)

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_similarity = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
# Build a 1-dimensional array with movie titles
indices = pd.Series(movies.index, index=movies['title'])

# Function that get movie recommendations based on the cosine similarity score of movie genres
def genre_recommendations(title):
    idx = indices[title]
    similar_scores = list(enumerate(cosine_similarity[idx]))
    similar_scores = sorted(similar_scores, key=lambda x: x[1], reverse=True)
    similar_scores = similar_scores[1:50]
    movie_indexes= [i[0] for i in similar_scores]
    return movies['title'].iloc[movie_indexes]

# %%
genre_recommendations('Good Will Hunting (1997)').head(20)
# Out:
# 25                                        Othello (1995)
# 26                                   Now and Then (1995)
# 29     Shanghai Triad (Yao a yao yao dao waipo qiao) ...
# 30                                Dangerous Minds (1995)
# 35                               Dead Man Walking (1995)
# 39                       Cry, the Beloved Country (1995)
# 42                                    Restoration (1995)
# 52                                       Lamerica (1994)
# 54                                        Georgia (1995)
# 56                          Home for the Holidays (1995)
# 61                             Mr. Holland's Opus (1995)
# 66                                       Two Bits (1995)
# 77                            Crossing Guard, The (1995)
# 79          White Balloon, The (Badkonake Sefid ) (1995)
# 81                       Antonia's Line (Antonia) (1995)
# 82       Once Upon a Time... When We Were Colored (1995)
# 89                    Journey of August King, The (1995)
# 92                                Beautiful Girls (1996)
# 95                               Hate (Haine, La) (1995)
# 112                             Margaret's Museum (1995)
# Name: title, dtype: object

# %%
indices
# Out:
# title
# Toy Story (1995)                                           0
# Jumanji (1995)                                             1
# Grumpier Old Men (1995)                                    2
# Waiting to Exhale (1995)                                   3
# Father of the Bride Part II (1995)                         4
# Heat (1995)                                                5
# Sabrina (1995)                                             6
# Tom and Huck (1995)                                        7
# Sudden Death (1995)                                        8
# GoldenEye (1995)                                           9
# American President, The (1995)                            10
# Dracula: Dead and Loving It (1995)                        11
# Balto (1995)                                              12
# Nixon (1995)                                              13
# Cutthroat Island (1995)                                   14
# Casino (1995)                                             15
# Sense and Sensibility (1995)                              16
# Four Rooms (1995)                                         17
# Ace Ventura: When Nature Calls (1995)                     18
# Money Train (1995)                                        19
# Get Shorty (1995)                                         20
# Copycat (1995)                                            21
# Assassins (1995)                                          22
# Powder (1995)                                             23
# Leaving Las Vegas (1995)                                  24
# Othello (1995)                                            25
# Now and Then (1995)                                       26
# Persuasion (1995)                                         27
# City of Lost Children, The (1995)                         28
# Shanghai Triad (Yao a yao yao dao waipo qiao) (1995)      29
#                                                         ...
# Return of the Fly (1959)                                3853
# Pajama Party (1964)                                     3854
# Stranger Than Paradise (1984)                           3855
# Voyage to the Bottom of the Sea (1961)                  3856
# Fantastic Voyage (1966)                                 3857
# Abbott and Costello Meet Frankenstein (1948)            3858
# Bank Dick, The (1940)                                   3859
# Creature From the Black Lagoon, The (1954)              3860
# Giant Gila Monster, The (1959)                          3861
# Invisible Man, The (1933)                               3862
# Killer Shrews, The (1959)                               3863
# Kronos (1957)                                           3864
# Kronos (1973)                                           3865
# Phantom of the Opera, The (1943)                        3866
# Runaway (1984)                                          3867
# Slumber Party Massacre, The (1982)                      3868
# Slumber Party Massacre II, The (1987)                   3869
# Slumber Party Massacre III, The (1990)                  3870
# Sorority House Massacre (1986)                          3871
# Sorority House Massacre II (1990)                       3872
# Bamboozled (2000)                                       3873
# Bootmen (2000)                                          3874
# Digimon: The Movie (2000)                               3875
# Get Carter (2000)                                       3876
# Get Carter (1971)                                       3877
# Meet the Parents (2000)                                 3878
# Requiem for a Dream (2000)                              3879
# Tigerland (2000)                                        3880
# Two Family House (2000)                                 3881
# Contender, The (2000)                                   3882
# Length: 3883, dtype: int64

# %%
combined_dataset.head()
# Out:
#    movie_id                                      title  \
# 0         1                           Toy Story (1995)
# 1        48                          Pocahontas (1995)
# 2       150                           Apollo 13 (1995)
# 3       260  Star Wars: Episode IV - A New Hope (1977)
# 4       527                    Schindler's List (1993)
#
#                                  genres  user_id  rating gender zipcode  \
# 0           Animation|Children's|Comedy        1       5      F   48067
# 1  Animation|Children's|Musical|Romance        1       5      F   48067
# 2                                 Drama        1       5      F   48067
# 3       Action|Adventure|Fantasy|Sci-Fi        1       4      F   48067
# 4                             Drama|War        1       5      F   48067
#
#   age_description occupation_description
# 0             <18           K-12 student
# 1             <18           K-12 student
# 2             <18           K-12 student
# 3             <18           K-12 student
# 4             <18           K-12 student

# %% [markdown]
# # ITEM BASED COLLABORATIVE FILTERING

# %%
movieRatings = combined_dataset.pivot_table(index=['user_id'],columns=['title'],values='rating')

# %%
movieRatings.head()
# Out:
# title    $1,000,000 Duck (1971)  'Night Mother (1986)  \
# user_id
# 1                           NaN                   NaN
# 2                           NaN                   NaN
# 3                           NaN                   NaN
# 4                           NaN                   NaN
# 5                           NaN                   NaN
#
# title    'Til There Was You (1997)  'burbs, The (1989)  \
# user_id
# 1                              NaN                 NaN
# 2                              NaN                 NaN
# 3                              NaN                 NaN
# 4                              NaN                 NaN
# 5                              NaN                 NaN
#
# title    ...And Justice for All (1979)  1-900 (1994)  \
# user_id
# 1                                  NaN           NaN
# 2                                  NaN           NaN
# 3                                  NaN           NaN
# 4                                  NaN           NaN
# 5                                  NaN           NaN
#
# title    10 Things I Hate About You (1999)  101 Dalmatians (1961)  \
# user_id
# 1                                      NaN                    NaN
# 2                                      NaN                    NaN
# 3                                      NaN                    NaN
# 4                                      NaN                    NaN
# 5                                      NaN                    NaN
#
# title    101 Dalmatians (1996)  12 Angry Men (1957)       ...         \
# user_id                                                   ...
# 1                          NaN                  NaN       ...
# 2                          NaN                  NaN       ...
# 3                          NaN                  NaN       ...
# 4                          NaN                  NaN       ...
# 5                          NaN                  NaN       ...
#
# title    Young Poisoner's Handbook, The (1995)  Young Sherlock Holmes (1985)  \
# user_id
# 1                                          NaN                           NaN
# 2                                          NaN                           NaN
# 3                                          NaN                           NaN
# 4                                          NaN                           NaN
# 5                                          NaN                           NaN
#
# title    Young and Innocent (1937)  Your Friends and Neighbors (1998)  \
# user_id
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
# 5                              NaN                                NaN
#
# title    Zachariah (1971)  Zed & Two Noughts, A (1985)  Zero Effect (1998)  \
# user_id
# 1                     NaN                          NaN                 NaN
# 2                     NaN                          NaN                 NaN
# 3                     NaN                          NaN                 NaN
# 4                     NaN                          NaN                 NaN
# 5                     NaN                          NaN                 NaN
#
# title    Zero Kelvin (Kjærlighetens kjøtere) (1995)  Zeus and Roxanne (1997)  \
# user_id
# 1                                               NaN                      NaN
# 2                                               NaN                      NaN
# 3                                               NaN                      NaN
# 4                                               NaN                      NaN
# 5                                               NaN                      NaN
#
# title    eXistenZ (1999)
# user_id
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
#
# [5 rows x 3706 columns]

# %%
movieRatings.head(50)
# Out:
# title    $1,000,000 Duck (1971)  'Night Mother (1986)  \
# user_id
# 1                           NaN                   NaN
# 2                           NaN                   NaN
# 3                           NaN                   NaN
# 4                           NaN                   NaN
# 5                           NaN                   NaN
# 6                           NaN                   NaN
# 7                           NaN                   NaN
# 8                           NaN                   NaN
# 9                           NaN                   NaN
# 10                          NaN                   NaN
# 11                          NaN                   NaN
# 12                          NaN                   NaN
# 13                          NaN                   NaN
# 14                          NaN                   NaN
# 15                          NaN                   NaN
# 16                          NaN                   NaN
# 17                          NaN                   NaN
# 18                          NaN                   NaN
# 19                          NaN                   NaN
# 20                          NaN                   NaN
# 21                          NaN                   NaN
# 22                          NaN                   NaN
# 23                          NaN                   NaN
# 24                          NaN                   NaN
# 25                          NaN                   NaN
# 26                          NaN                   NaN
# 27                          NaN                   NaN
# 28                          NaN                   NaN
# 29                          NaN                   NaN
# 30                          NaN                   NaN
# 31                          NaN                   NaN
# 32                          NaN                   NaN
# 33                          NaN                   NaN
# 34                          NaN                   NaN
# 35                          NaN                   NaN
# 36                          NaN                   NaN
# 37                          NaN                   NaN
# 38                          NaN                   NaN
# 39                          NaN                   NaN
# 40                          NaN                   NaN
# 41                          NaN                   NaN
# 42                          NaN                   NaN
# 43                          NaN                   NaN
# 44                          NaN                   NaN
# 45                          NaN                   NaN
# 46                          NaN                   NaN
# 47                          NaN                   NaN
# 48                          NaN                   NaN
# 49                          NaN                   NaN
# 50                          NaN                   NaN
#
# title    'Til There Was You (1997)  'burbs, The (1989)  \
# user_id
# 1                              NaN                 NaN
# 2                              NaN                 NaN
# 3                              NaN                 NaN
# 4                              NaN                 NaN
# 5                              NaN                 NaN
# 6                              NaN                 NaN
# 7                              NaN                 NaN
# 8                              NaN                 NaN
# 9                              NaN                 NaN
# 10                             NaN                 4.0
# 11                             NaN                 NaN
# 12                             NaN                 NaN
# 13                             NaN                 NaN
# 14                             NaN                 NaN
# 15                             NaN                 NaN
# 16                             NaN                 NaN
# 17                             NaN                 NaN
# 18                             NaN                 NaN
# 19                             NaN                 NaN
# 20                             NaN                 NaN
# 21                             NaN                 NaN
# 22                             NaN                 4.0
# 23                             NaN                 NaN
# 24                             NaN                 NaN
# 25                             NaN                 NaN
# 26                             NaN                 NaN
# 27                             NaN                 NaN
# 28                             NaN                 NaN
# 29                             NaN                 NaN
# 30                             NaN                 NaN
# 31                             NaN                 NaN
# 32                             NaN                 NaN
# 33                             NaN                 NaN
# 34                             NaN                 2.0
# 35                             NaN                 NaN
# 36                             NaN                 NaN
# 37                             NaN                 NaN
# 38                             2.0                 NaN
# 39                             NaN                 NaN
# 40                             NaN                 NaN
# 41                             NaN                 NaN
# 42                             NaN                 NaN
# 37                    NaN                          NaN                 NaN
# 38                    NaN                          NaN                 NaN
# 39                    NaN                          NaN                 NaN
# 40                    NaN                          NaN                 NaN
# 41                    NaN                          NaN                 NaN
# 42                    NaN                          NaN                 NaN
# 43                    NaN                          NaN                 NaN
# 44                    NaN                          NaN                 NaN
# 45                    NaN                          NaN                 NaN
# 46                    NaN                          NaN                 NaN
# 47                    NaN                          NaN                 NaN
# 48                    NaN                          NaN                 NaN
# 49                    NaN                          NaN                 NaN
# 50                    NaN                          NaN                 NaN
#
# title    Zero Kelvin (Kjærlighetens kjøtere) (1995)  Zeus and Roxanne (1997)  \
# user_id
# 1                                               NaN                      NaN
# 2                                               NaN                      NaN
# 3                                               NaN                      NaN
# 4                                               NaN                      NaN
# 5                                               NaN                      NaN
# 6                                               NaN                      NaN
# 7                                               NaN                      NaN
# 8                                               NaN                      NaN
# 9                                               NaN                      NaN
# 10                                              NaN                      NaN
# 11                                              NaN                      NaN
# 12                                              NaN                      NaN
# 13                                              NaN                      NaN
# 14                                              NaN                      NaN
# 15                                              NaN                      NaN
# 16                                              NaN                      NaN
# 17                                              NaN                      NaN
# 18                                              NaN                      NaN
# 19                                              NaN                      NaN
# 20                                              NaN                      NaN
# 21                                              NaN                      NaN
# 22                                              NaN                      NaN
# 23                                              NaN                      NaN
# 24                                              NaN                      NaN
# 25                                              NaN                      NaN
# 26                                              NaN                      NaN
# 27                                              NaN                      NaN
# 28                                              NaN                      NaN
# 29                                              NaN                      NaN
# 30                                              NaN                      NaN
# 31                                              NaN                      NaN
# 32                                              NaN                      NaN
# 33                                              NaN                      NaN
# 34                                              NaN                      NaN
# 35                                              NaN                      NaN
# 36                                              NaN                      NaN
# 37                                              NaN                      NaN
# 38                                              NaN                      NaN
# 39                                              NaN                      NaN
# 40                                              NaN                      NaN
# 41                                              NaN                      NaN
# 42                                              NaN                      NaN
# 43                                              NaN                      NaN
# 44                                              NaN                      NaN
# 45                                              NaN                      NaN
# 46                                              NaN                      NaN
# 47                                              NaN                      NaN
# 48                                              NaN                      NaN
# 49                                              NaN                      NaN
# 50                                              NaN                      NaN
#
# title    eXistenZ (1999)
# user_id
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    2.0
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# 15                   NaN
# 16                   NaN
# 17                   3.0
# 18                   NaN
# 19                   1.0
# 20                   NaN
# 21                   NaN
# 22                   NaN
# 23                   4.0
# 24                   NaN
# 25                   NaN
# 26                   NaN
# 27                   NaN
# 28                   NaN
# 29                   NaN
# 30                   NaN
# 31                   NaN
# 32                   NaN
# 33                   NaN
# 34                   NaN
# 35                   NaN
# 36                   NaN
# 37                   NaN
# 38                   NaN
# 39                   NaN
# 40                   NaN
# 41                   NaN
# 42                   NaN
# 43                   NaN
# 44                   NaN
# 45                   NaN
# 46                   NaN
# 47                   NaN
# 48                   NaN
# 49                   NaN
# 50                   NaN
#
# [50 rows x 3706 columns]

# %%
corrMatrix = movieRatings.corr()
corrMatrix.head()
# Out:
# title                          $1,000,000 Duck (1971)  'Night Mother (1986)  \
# title
# $1,000,000 Duck (1971)                       1.000000              0.522233
# 'Night Mother (1986)                         0.522233              1.000000
# 'Til There Was You (1997)                         NaN             -0.177705
# 'burbs, The (1989)                           0.000000              0.240000
# ...And Justice for All (1979)                0.422577              0.216272
#
# title                          'Til There Was You (1997)  'burbs, The (1989)  \
# title
# $1,000,000 Duck (1971)                               NaN            0.000000
# 'Night Mother (1986)                           -0.177705            0.240000
# 'Til There Was You (1997)                       1.000000            0.712627
# 'burbs, The (1989)                              0.712627            1.000000
# ...And Justice for All (1979)                   0.719676            0.089727
#
# title                          ...And Justice for All (1979)  1-900 (1994)  \
# title
# $1,000,000 Duck (1971)                              0.422577           NaN
# 'Night Mother (1986)                                0.216272           NaN
# 'Til There Was You (1997)                           0.719676           NaN
# 'burbs, The (1989)                                  0.089727           NaN
# ...And Justice for All (1979)                       1.000000           NaN
#
# title                          10 Things I Hate About You (1999)  \
# title
# $1,000,000 Duck (1971)                                 -0.449490
# 'Night Mother (1986)                                    0.266158
# 'Til There Was You (1997)                               0.300273
# 'burbs, The (1989)                                      0.189689
# ...And Justice for All (1979)                           0.291124
#
# title                          101 Dalmatians (1961)  101 Dalmatians (1996)  \
# title
# $1,000,000 Duck (1971)                      0.561074               0.150584
# 'Night Mother (1986)                        0.220347              -0.199239
# 'Til There Was You (1997)                   0.457984               0.564288
# 'burbs, The (1989)                          0.088541               0.101064
# ...And Justice for All (1979)               0.166965              -0.142597
#
# title                          12 Angry Men (1957)       ...         \
# title                                                    ...
# $1,000,000 Duck (1971)                    0.125209       ...
# 'Night Mother (1986)                      0.213733       ...
# 'Til There Was You (1997)                 0.210259       ...
# 'burbs, The (1989)                        0.047590       ...
# ...And Justice for All (1979)             0.303093       ...
#
# title                          Young Poisoner's Handbook, The (1995)  \
# title
# $1,000,000 Duck (1971)                                      1.000000
# 'Night Mother (1986)                                        0.774597
# 'Til There Was You (1997)                                        NaN
# 'burbs, The (1989)                                          0.355654
# ...And Justice for All (1979)                              -0.279257
#
# title                          Young Sherlock Holmes (1985)  \
# title
# $1,000,000 Duck (1971)                            -0.106243
# 'Night Mother (1986)                              -0.276359
# 'Til There Was You (1997)                         -0.016137
# 'burbs, The (1989)                                 0.278425
# ...And Justice for All (1979)                      0.052517
#
# title                          Young and Innocent (1937)  \
# title
# $1,000,000 Duck (1971)                               NaN
# 'Night Mother (1986)                            1.000000
# 'Til There Was You (1997)                            NaN
# 'burbs, The (1989)                                   NaN
# ...And Justice for All (1979)                   0.310087
#
# title                          Your Friends and Neighbors (1998)  \
# title
# $1,000,000 Duck (1971)                                  0.000000
# 'Night Mother (1986)                                   -0.052758
# 'Til There Was You (1997)                               0.059235
# 'burbs, The (1989)                                      0.158997
# ...And Justice for All (1979)                           0.159503
#
# title                          Zachariah (1971)  Zed & Two Noughts, A (1985)  \
# title
# $1,000,000 Duck (1971)                      NaN                    -1.000000
# 'Night Mother (1986)                        NaN                    -0.492518
# 'Til There Was You (1997)                   NaN                          NaN
# 'burbs, The (1989)                          NaN                     0.080064
# ...And Justice for All (1979)               NaN                    -0.542037
#
# title                          Zero Effect (1998)  \
# title
# $1,000,000 Duck (1971)                   0.000000
# 'Night Mother (1986)                     0.082580
# 'Til There Was You (1997)                0.183855
# 'burbs, The (1989)                       0.039503
# ...And Justice for All (1979)            0.200237
#
# title                          Zero Kelvin (Kjærlighetens kjøtere) (1995)  \
# title
# $1,000,000 Duck (1971)                                                NaN
# 'Night Mother (1986)                                                  NaN
# 'Til There Was You (1997)                                             NaN
# 'burbs, The (1989)                                                    NaN
# ...And Justice for All (1979)                                         NaN
#
# title                          Zeus and Roxanne (1997)  eXistenZ (1999)
# title
# $1,000,000 Duck (1971)                        0.944911        -0.500000
# 'Night Mother (1986)                               NaN         0.100372
# 'Til There Was You (1997)                     1.000000         0.303731
# 'burbs, The (1989)                            0.000000         0.135172
# ...And Justice for All (1979)                      NaN        -0.024037
#
# [5 rows x 3706 columns]

# %%
#Use Pearson Correlation 

corrMatrix = movieRatings.corr(method='pearson', min_periods=100)
corrMatrix.head()
# Out:
# title                          $1,000,000 Duck (1971)  'Night Mother (1986)  \
# title
# $1,000,000 Duck (1971)                            NaN                   NaN
# 'Night Mother (1986)                              NaN                   NaN
# 'Til There Was You (1997)                         NaN                   NaN
# 'burbs, The (1989)                                NaN                   NaN
# ...And Justice for All (1979)                     NaN                   NaN
#
# title                          'Til There Was You (1997)  'burbs, The (1989)  \
# title
# $1,000,000 Duck (1971)                               NaN                 NaN
# 'Night Mother (1986)                                 NaN                 NaN
# 'Til There Was You (1997)                            NaN                 NaN
# 'burbs, The (1989)                                   NaN                 1.0
# ...And Justice for All (1979)                        NaN                 NaN
#
# title                          ...And Justice for All (1979)  1-900 (1994)  \
# title
# $1,000,000 Duck (1971)                                   NaN           NaN
# 'Night Mother (1986)                                     NaN           NaN
# 'Til There Was You (1997)                                NaN           NaN
# 'burbs, The (1989)                                       NaN           NaN
# ...And Justice for All (1979)                            1.0           NaN
#
# title                          10 Things I Hate About You (1999)  \
# title
# $1,000,000 Duck (1971)                                       NaN
# 'Night Mother (1986)                                         NaN
# 'Til There Was You (1997)                                    NaN
# 'burbs, The (1989)                                           NaN
# ...And Justice for All (1979)                                NaN
#
# title                          101 Dalmatians (1961)  101 Dalmatians (1996)  \
# title
# $1,000,000 Duck (1971)                           NaN                    NaN
# 'Night Mother (1986)                             NaN                    NaN
# 'Til There Was You (1997)                        NaN                    NaN
# 'burbs, The (1989)                          0.088541                    NaN
# ...And Justice for All (1979)                    NaN                    NaN
#
# title                          12 Angry Men (1957)       ...         \
# title                                                    ...
# $1,000,000 Duck (1971)                         NaN       ...
# 'Night Mother (1986)                           NaN       ...
# 'Til There Was You (1997)                      NaN       ...
# 'burbs, The (1989)                             NaN       ...
# ...And Justice for All (1979)                  NaN       ...
#
# title                          Young Poisoner's Handbook, The (1995)  \
# title
# $1,000,000 Duck (1971)                                           NaN
# 'Night Mother (1986)                                             NaN
# 'Til There Was You (1997)                                        NaN
# 'burbs, The (1989)                                               NaN
# ...And Justice for All (1979)                                    NaN
#
# title                          Young Sherlock Holmes (1985)  \
# title
# $1,000,000 Duck (1971)                                  NaN
# 'Night Mother (1986)                                    NaN
# 'Til There Was You (1997)                               NaN
# 'burbs, The (1989)                                      NaN
# ...And Justice for All (1979)                           NaN
#
# title                          Young and Innocent (1937)  \
# title
# $1,000,000 Duck (1971)                               NaN
# 'Night Mother (1986)                                 NaN
# 'Til There Was You (1997)                            NaN
# 'burbs, The (1989)                                   NaN
# ...And Justice for All (1979)                        NaN
#
# title                          Your Friends and Neighbors (1998)  \
# title
# $1,000,000 Duck (1971)                                       NaN
# 'Night Mother (1986)                                         NaN
# 'Til There Was You (1997)                                    NaN
# 'burbs, The (1989)                                           NaN
# ...And Justice for All (1979)                                NaN
#
# title                          Zachariah (1971)  Zed & Two Noughts, A (1985)  \
# title
# $1,000,000 Duck (1971)                      NaN                          NaN
# 'Night Mother (1986)                        NaN                          NaN
# 'Til There Was You (1997)                   NaN                          NaN
# 'burbs, The (1989)                          NaN                          NaN
# ...And Justice for All (1979)               NaN                          NaN
#
# title                          Zero Effect (1998)  \
# title
# $1,000,000 Duck (1971)                        NaN
# 'Night Mother (1986)                          NaN
# 'Til There Was You (1997)                     NaN
# 'burbs, The (1989)                            NaN
# ...And Justice for All (1979)                 NaN
#
# title                          Zero Kelvin (Kjærlighetens kjøtere) (1995)  \
# title
# $1,000,000 Duck (1971)                                                NaN
# 'Night Mother (1986)                                                  NaN
# 'Til There Was You (1997)                                             NaN
# 'burbs, The (1989)                                                    NaN
# ...And Justice for All (1979)                                         NaN
#
# title                          Zeus and Roxanne (1997)  eXistenZ (1999)
# title
# $1,000,000 Duck (1971)                             NaN              NaN
# 'Night Mother (1986)                               NaN              NaN
# 'Til There Was You (1997)                          NaN              NaN
# 'burbs, The (1989)                                 NaN              NaN
# ...And Justice for All (1979)                      NaN              NaN
#
# [5 rows x 3706 columns]

# %%
randomRatings = movieRatings.loc[10].dropna()

# %%
randomRatings
# Out:
# title
# 'burbs, The (1989)                                        4.0
# 12 Angry Men (1957)                                       3.0
# 13th Warrior, The (1999)                                  4.0
# 20,000 Leagues Under the Sea (1954)                       4.0
# 2001: A Space Odyssey (1968)                              3.0
# 7th Voyage of Sinbad, The (1958)                          2.0
# Abbott and Costello Meet Frankenstein (1948)              4.0
# Absent Minded Professor, The (1961)                       5.0
# Abyss, The (1989)                                         4.0
# Ace Ventura: Pet Detective (1994)                         4.0
# Addams Family, The (1991)                                 3.0
# Adventures in Babysitting (1987)                          4.0
# Affair to Remember, An (1957)                             2.0
# African Queen, The (1951)                                 3.0
# Airplane! (1980)                                          4.0
# Aladdin (1992)                                            4.0
# Alice in Wonderland (1951)                                4.0
# Alien (1979)                                              4.0
# Alien Nation (1988)                                       3.0
# Alien: Resurrection (1997)                                4.0
# Aliens (1986)                                             5.0
# Alien³ (1992)                                             3.0
# All About Eve (1950)                                      4.0
# All Quiet on the Western Front (1930)                     3.0
# Amadeus (1984)                                            4.0
# American Beauty (1999)                                    3.0
# American Graffiti (1973)                                  5.0
# Anna and the King (1999)                                  5.0
# Anne Frank Remembered (1995)                              3.0
# Annie Hall (1977)                                         4.0
#                                                          ...
# Toy Story (1995)                                          5.0
# Toy Story 2 (1999)                                        4.0
# Trading Places (1983)                                     4.0
# Treasure of the Sierra Madre, The (1948)                  3.0
# Trekkies (1997)                                           5.0
# Tron (1982)                                               5.0
# Truman Show, The (1998)                                   5.0
# Twelve Monkeys (1995)                                     5.0
# Ulee's Gold (1997)                                        4.0
# Vacation (1983)                                           3.0
# Wallace & Gromit: The Best of Aardman Animation (1996)    5.0
# War of the Worlds, The (1953)                             4.0
# Watership Down (1978)                                     3.0
# Waterworld (1995)                                         4.0
# Way We Were, The (1973)                                   4.0
# Wayne's World 2 (1993)                                    3.0
# Weekend at Bernie's (1989)                                3.0
# West Side Story (1961)                                    5.0
# What About Bob? (1991)                                    5.0
# When Harry Met Sally... (1989)                            5.0
# While You Were Sleeping (1995)                            5.0
# White Christmas (1954)                                    5.0
# William Shakespeare's Romeo and Juliet (1996)             5.0
# Willow (1988)                                             5.0
# Willy Wonka and the Chocolate Factory (1971)              5.0
# Winnie the Pooh and the Blustery Day (1968)               5.0
# Wizard of Oz, The (1939)                                  5.0
# Wrong Trousers, The (1993)                                5.0
# You've Got Mail (1998)                                    5.0
# Young Frankenstein (1974)                                 5.0
# Name: 10, Length: 401, dtype: float64

# %%
def getSimilarCandidates(userId):
    similarCandidates = pd.Series()
    userRatings = movieRatings.loc[userId].dropna()
    for i in range(0, len(userRatings.index)):
        print(f"Adding similar movies to {randomRatings.index[i]}...")
        similars = corrMatrix[userRatings.index[i]].dropna()
        #Scale
        similars = similars.map(lambda x: x * userRatings[i])
        similarCandidates = similarCandidates.append(similars)
        
    similarCandidates.groupby(similarCandidates.index).sum()
    similarCandidates.sort_values(inplace=True,ascending=False)
    
    similarCandidates = similarCandidates.drop(userRatings.index)
    
    return similarCandidates

# %%
similarMovies = getSimilarCandidates(1)
print(similarMovies.head(10))
# Out:
# Adding similar movies to 'burbs, The (1989)...
# Adding similar movies to 12 Angry Men (1957)...
# Adding similar movies to 13th Warrior, The (1999)...
# Adding similar movies to 20,000 Leagues Under the Sea (1954)...
# Adding similar movies to 2001: A Space Odyssey (1968)...
# Adding similar movies to 7th Voyage of Sinbad, The (1958)...
# Adding similar movies to Abbott and Costello Meet Frankenstein (1948)...
# Adding similar movies to Absent Minded Professor, The (1961)...
# Adding similar movies to Abyss, The (1989)...
# Adding similar movies to Ace Ventura: Pet Detective (1994)...
# Adding similar movies to Addams Family, The (1991)...
# Adding similar movies to Adventures in Babysitting (1987)...
# Adding similar movies to Affair to Remember, An (1957)...
# Adding similar movies to African Queen, The (1951)...
# Adding similar movies to Airplane! (1980)...
# Adding similar movies to Aladdin (1992)...
# Adding similar movies to Alice in Wonderland (1951)...
# Adding similar movies to Alien (1979)...
# Adding similar movies to Alien Nation (1988)...
# Adding similar movies to Alien: Resurrection (1997)...
# Adding similar movies to Aliens (1986)...
# Adding similar movies to Alien³ (1992)...
# Adding similar movies to All About Eve (1950)...
# Adding similar movies to All Quiet on the Western Front (1930)...
# Adding similar movies to Amadeus (1984)...
# Adding similar movies to American Beauty (1999)...
# Adding similar movies to American Graffiti (1973)...
# Adding similar movies to Anna and the King (1999)...
# Adding similar movies to Anne Frank Remembered (1995)...
# Adding similar movies to Annie Hall (1977)...
# Adding similar movies to Antz (1998)...
# Adding similar movies to Apollo 13 (1995)...
# Adding similar movies to Army of Darkness (1993)...
# Adding similar movies to Arsenic and Old Lace (1944)...
# Adding similar movies to As Good As It Gets (1997)...
# Adding similar movies to Austin Powers: International Man of Mystery (1997)...
# Adding similar movies to Bachelor Party (1984)...
# Adding similar movies to Back to the Future (1985)...
# Adding similar movies to Back to the Future Part II (1989)...
# Adding similar movies to Back to the Future Part III (1990)...
# Adding similar movies to Bad Seed, The (1956)...
# Adding similar movies to Bambi (1942)...
# Adding similar movies to Batman (1989)...
# Adding similar movies to Batman Forever (1995)...
# Adding similar movies to Batman Returns (1992)...
# Adding similar movies to Battlefield Earth (2000)...
# Adding similar movies to Beauty and the Beast (1991)...
# Adding similar movies to Bedknobs and Broomsticks (1971)...
# Adding similar movies to Beetlejuice (1988)...
# Adding similar movies to Being John Malkovich (1999)...
# Adding similar movies to Being There (1979)...
# Adding similar movies to Ben-Hur (1959)...
# Adding similar movies to Beneath the Planet of the Apes (1970)...
# Sleeping Beauty (1959)                         3.562989
# Pinocchio (1940)                               3.323988
# Lady and the Tramp (1955)                      3.306947
# Peter Pan (1953)                               3.213585
# Pinocchio (1940)                               3.060689
# Rescuers, The (1977)                           3.044621
# Winnie the Pooh and the Blustery Day (1968)    3.021659
# Back to the Future Part II (1989)              2.952365
# Robin Hood (1973)                              2.946287
# Rescuers Down Under, The (1990)                2.922292
# dtype: float64

# %%
movieRatings.loc[1]
# Out:
# title
# $1,000,000 Duck (1971)                           NaN
# 'Night Mother (1986)                             NaN
# 'Til There Was You (1997)                        NaN
# 'burbs, The (1989)                               NaN
# ...And Justice for All (1979)                    NaN
# 1-900 (1994)                                     NaN
# 10 Things I Hate About You (1999)                NaN
# 101 Dalmatians (1961)                            NaN
# 101 Dalmatians (1996)                            NaN
# 12 Angry Men (1957)                              NaN
# 13th Warrior, The (1999)                         NaN
# 187 (1997)                                       NaN
# 2 Days in the Valley (1996)                      NaN
# 20 Dates (1998)                                  NaN
# 20,000 Leagues Under the Sea (1954)              NaN
# 200 Cigarettes (1999)                            NaN
# 2001: A Space Odyssey (1968)                     NaN
# 2010 (1984)                                      NaN
# 24 7: Twenty Four Seven (1997)                   NaN
# 24-hour Woman (1998)                             NaN
# 28 Days (2000)                                   NaN
# 3 Ninjas: High Noon On Mega Mountain (1998)      NaN
# 3 Strikes (2000)                                 NaN
# 301, 302 (1995)                                  NaN
# 39 Steps, The (1935)                             NaN
# 400 Blows, The (Les Quatre cents coups) (1959)   NaN
# 42 Up (1998)                                     NaN
# 52 Pick-Up (1986)                                NaN
# 54 (1998)                                        NaN
# 7th Voyage of Sinbad, The (1958)                 NaN
#                                                   ..
# Wrongfully Accused (1998)                        NaN
# Wyatt Earp (1994)                                NaN
# X-Files: Fight the Future, The (1998)            NaN
# X-Men (2000)                                     NaN
# X: The Unknown (1956)                            NaN
# Xiu Xiu: The Sent-Down Girl (Tian yu) (1998)     NaN
# Yankee Zulu (1994)                               NaN
# Yards, The (1999)                                NaN
# Year My Voice Broke, The (1987)                  NaN
# Year of Living Dangerously (1982)                NaN
# Year of the Horse (1997)                         NaN
# Yellow Submarine (1968)                          NaN
# Yojimbo (1961)                                   NaN
# You Can't Take It With You (1938)                NaN
# You So Crazy (1994)                              NaN
# You've Got Mail (1998)                           NaN
# Young Doctors in Love (1982)                     NaN
# Young Frankenstein (1974)                        NaN
# Young Guns (1988)                                NaN
# Young Guns II (1990)                             NaN
# Young Poisoner's Handbook, The (1995)            NaN
# Young Sherlock Holmes (1985)                     NaN
# Young and Innocent (1937)                        NaN
# Your Friends and Neighbors (1998)                NaN
# Zachariah (1971)                                 NaN
# Zed & Two Noughts, A (1985)                      NaN
# Zero Effect (1998)                               NaN
# Zero Kelvin (Kjærlighetens kjøtere) (1995)       NaN
# Zeus and Roxanne (1997)                          NaN
# eXistenZ (1999)                                  NaN
# Name: 1, Length: 3706, dtype: float64

# %% [markdown]
# ### Evaluation of Item-Item and User-User

# %%
ratings['user_id'] = ratings['user_id'].fillna(0)
ratings['movie_id'] = ratings['movie_id'].fillna(0)

ratings['rating'] = ratings['rating'].fillna(ratings['rating'].mean())

# %%
from sklearn import cross_validation as cv

training_data, test_data = cv.train_test_split(subset,test_size=0.2)

# %%
subset = ratings.sample(frac=0.02)

# %%
training_data_matrix = training_data.as_matrix(columns=['user_id', 'movie_id', 'rating'])
testing_data_matrix = test_data.as_matrix(columns=['user_id', 'movie_id', 'rating'])

# %%
from sklearn.metrics.pairwise import pairwise_distances

user_correlation = 1 - pairwise_distances(training_data, metric='correlation')
user_correlation[np.isnan(user_correlation)] = 0

# %%
item_correlation = 1 - pairwise_distances(training_data_matrix.T, metric='correlation')
item_correlation[np.isnan(item_correlation)] = 0

# %%
def predict(ratings, similarity, type='user'):
    if type == 'user':
        mean_user_rating = ratings.mean(axis=1)
        # Use np.newaxis so that mean_user_rating has same format as ratings
        ratings_diff = (ratings - mean_user_rating[:, np.newaxis])
        pred = mean_user_rating[:, np.newaxis] + similarity.dot(ratings_diff) / np.array([np.abs(similarity).sum(axis=1)]).T
    elif type == 'item':
        pred = ratings.dot(similarity) / np.array([np.abs(similarity).sum(axis=1)])
    return pred

# %%
predict(training_data_matrix, user_correlation,type='user')
# Out:
# array([[ 4502.47000311,  2798.51005435,  1067.01994254],
#        [ 4461.67192263,  2675.36989178,   979.9581856 ],
#        [ 4482.76501498,  2603.11861941,   960.11636561],
#        ...,
#        [ 3342.23967002,  1281.58544407,  -214.82511409],
#        [ 3596.66088176,  1750.22800879,    87.11110945],
#        [ 4230.12737833,  2636.55438465,   865.31823702]])

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# Function to calculate RMSE
def rmse(pred, actual):
    # Ignore nonzero terms.
    pred = pred[actual.nonzero()].flatten()
    actual = actual[actual.nonzero()].flatten()
    return sqrt(mean_squared_error(pred, actual))

# %%
user_prediction = predict(training_data_matrix, user_correlation, type='user')
item_prediction = predict(training_data_matrix, item_correlation, type='item')

# RMSE on the test data
print('User-based CF RMSE: ' + str(rmse(user_prediction, testing_data_matrix)))
print('Item-based CF RMSE: ' + str(rmse(item_prediction, testing_data_matrix)))
# Out:
# User-based CF RMSE: 1426.6489686207692
# Item-based CF RMSE: 1641.4576260491742

# %%
print('User-based CF RMSE: ' + str(rmse(user_prediction, training_data_matrix)))
print('Item-based CF RMSE: ' + str(rmse(item_prediction, training_data_matrix)))
# Out:
# User-based CF RMSE: 696.1703994841617
# Item-based CF RMSE: 162.23468979632517

# %%
import numpy as np
from keras.layers import Embedding, Reshape, Merge, Dropout, Dense
from keras.callbacks import Callback, EarlyStopping, ModelCheckpoint
from keras.models import Sequential

class CFModel(Sequential):

    def __init__(self, n_users, m_items, k_factors, **kwargs):
        P = Sequential()
        P.add(Embedding(n_users, k_factors, input_length=1))
        P.add(Reshape((k_factors,)))
        Q = Sequential()
        Q.add(Embedding(m_items, k_factors, input_length=1))
        Q.add(Reshape((k_factors,)))
        super(CFModel, self).__init__(**kwargs)
        self.add(Merge([P, Q], mode='dot', dot_axes=1))

    def rate(self, user_id, item_id):
        return self.predict([np.array([user_id]), np.array([item_id])])[0][0]

class DeepModel(Sequential):

    def __init__(self, n_users, m_items, k_factors, p_dropout=0.1, **kwargs):
        P = Sequential()
        P.add(Embedding(n_users, k_factors, input_length=1))
        P.add(Reshape((k_factors,)))
        Q = Sequential()
        Q.add(Embedding(m_items, k_factors, input_length=1))
        Q.add(Reshape((k_factors,)))
        super(DeepModel, self).__init__(**kwargs)
        self.add(Merge([P, Q], mode='concat'))
        self.add(Dropout(p_dropout))
        self.add(Dense(k_factors, activation='relu'))
        self.add(Dropout(p_dropout))
        self.add(Dense(1, activation='linear'))

    def rate(self, user_id, item_id):
        return self.predict([np.array([user_id]), np.array([item_id])])[0][0]

# %%
# Create training set
shuffled_ratings = ratings.sample(frac=1., random_state=1)

# Shuffling users
Users = shuffled_ratings['user_embedded_id'].values
print('Users:', Users, ', shape =', Users.shape)

# Shuffling movies
Movies = shuffled_ratings['movie_embedded_id'].values
print('Movies:', Movies, ', shape =', Movies.shape)

# Shuffling ratings
Ratings = shuffled_ratings['rating'].values
print('Ratings:', Ratings, ', shape =', Ratings.shape)
# Out:
# Users: [3808 1388 4509 ..., 2898 3024  827] , shape = (1000209,)
# Movies: [2923 1956 1478 ..., 2663 1295 1380] , shape = (1000209,)
# Ratings: [4 4 2 ..., 4 5 2] , shape = (1000209,)

# %%
model = CFModel(max_userid, max_movieid,100)
model.compile(loss='mse', optimizer='adamax')
# Out:
# C:\Users\cyrus\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.

# %%
callbacks = [EarlyStopping('val_loss', patience=2), 
             ModelCheckpoint('weights.h5', save_best_only=True)]

# Use 30 epochs, 90% training data, 10% validation data 
history = model.fit([Users, Movies], Ratings, nb_epoch=30, validation_split=.1, verbose=2, callbacks=callbacks)
# Out:
# C:\Users\cyrus\Anaconda3\lib\site-packages\keras\models.py:944: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Train on 900188 samples, validate on 100021 samples
# Epoch 1/30
#  - 480s - loss: 8.2042 - val_loss: 2.2419
# Epoch 2/30
#  - 481s - loss: 1.4852 - val_loss: 1.1287
# Epoch 3/30
#  - 536s - loss: 1.0048 - val_loss: 0.9420
# Epoch 4/30
#  - 507s - loss: 0.8932 - val_loss: 0.8793
# Epoch 5/30
#  - 486s - loss: 0.8444 - val_loss: 0.8451
# Epoch 6/30
#  - 485s - loss: 0.8130 - val_loss: 0.8257
# Epoch 7/30
#  - 495s - loss: 0.7889 - val_loss: 0.8110
# Epoch 8/30
#  - 482s - loss: 0.7682 - val_loss: 0.7971
# Epoch 9/30
#  - 480s - loss: 0.7481 - val_loss: 0.7876
# Epoch 10/30
#  - 503s - loss: 0.7279 - val_loss: 0.7790
# Epoch 11/30
#  - 469s - loss: 0.7073 - val_loss: 0.7706
# Epoch 12/30
#  - 466s - loss: 0.6871 - val_loss: 0.7635
# Epoch 13/30
#  - 471s - loss: 0.6666 - val_loss: 0.7584
# Epoch 14/30
#  - 473s - loss: 0.6458 - val_loss: 0.7543
# Epoch 15/30
#  - 489s - loss: 0.6251 - val_loss: 0.7524
# Epoch 16/30
#  - 556s - loss: 0.6042 - val_loss: 0.7495
# Epoch 17/30
#  - 561s - loss: 0.5835 - val_loss: 0.7516
# Epoch 18/30
#  - 551s - loss: 0.5628 - val_loss: 0.7533
